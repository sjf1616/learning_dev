# %% [markdown]
# # Master Data Analysis with Python - Intro to Pandas
# ----
#
# This is a 2-hour course from Udemy

# %%
import pandas as pd

# %%
bikes = pd.read_csv("../data/Master_Data_Analysis/bikes.csv")
bikes
# Out:
#        gender            starttime             stoptime  tripduration  \
# 0        Male  2013-06-28 19:01:00  2013-06-28 19:17:00           993
# 1        Male  2013-06-28 22:53:00  2013-06-28 23:03:00           623
# 2        Male  2013-06-30 14:43:00  2013-06-30 15:01:00          1040
# 3        Male  2013-07-01 10:05:00  2013-07-01 10:16:00           667
# 4        Male  2013-07-01 11:16:00  2013-07-01 11:18:00           130
# ...       ...                  ...                  ...           ...
# 50084    Male  2017-12-30 13:07:00  2017-12-30 13:34:00          1625
# 50085    Male  2017-12-30 13:34:00  2017-12-30 13:44:00           585
# 50086    Male  2017-12-30 13:34:00  2017-12-30 13:48:00           824
# 50087  Female  2017-12-31 09:30:00  2017-12-31 09:33:00           178
# 50088    Male  2017-12-31 15:22:00  2017-12-31 15:26:00           214
#
#                   from_station_name  start_capacity  \
# 0         Lake Shore Dr & Monroe St            11.0
# 1      Clinton St & Washington Blvd            31.0
# 2      Sheffield Ave & Kingsbury St            15.0
# 3           Carpenter St & Huron St            19.0
# 4            Damen Ave & Pierce Ave            19.0
# ...                             ...             ...
# 50084         State St & Pearson St            27.0
# 50085      Halsted St & 35th St (*)            16.0
# 50086      Kingsbury St & Kinzie St            31.0
# 50087          Clinton St & Lake St            23.0
# 50088    Clarendon Ave & Leland Ave            15.0
#
#                      to_station_name  end_capacity  temperature  wind_speed  \
# 0              Michigan Ave & Oak St          15.0         73.9        12.7
# 1               Wells St & Walton St          19.0         69.1         6.9
# 2            Dearborn St & Monroe St          23.0         73.0        16.1
# 3             Clark St & Randolph St          31.0         72.0        16.1
# 4             Damen Ave & Pierce Ave          19.0         73.0        17.3
# ...                              ...           ...          ...         ...
# 50084              Clark St & Elm St          27.0          5.0        16.1
# 50085            Union Ave & Root St          11.0          5.0        16.1
# 50086  Halsted St & Blackhawk St (*)          20.0          5.0        16.1
# 50087       Kingsbury St & Kinzie St          31.0          7.0        11.5
# 50088     Clifton Ave & Lawrence Ave          15.0         10.9        15.0
#
#              events
# 0      mostlycloudy
# 1      partlycloudy
# 2      mostlycloudy
# 3      mostlycloudy
# 4      partlycloudy
# ...             ...
# 50084  partlycloudy
# 50085  partlycloudy
# 50086  partlycloudy
# 50087  partlycloudy
# 50088  partlycloudy
#
# [50089 rows x 11 columns]

# %% [markdown]
# **Selecionando Series no DataFrame**

# %%
bikes.head(3)
# Out:
#   gender            starttime             stoptime  tripduration  \
# 0   Male  2013-06-28 19:01:00  2013-06-28 19:17:00           993
# 1   Male  2013-06-28 22:53:00  2013-06-28 23:03:00           623
# 2   Male  2013-06-30 14:43:00  2013-06-30 15:01:00          1040
#
#               from_station_name  start_capacity          to_station_name  \
# 0     Lake Shore Dr & Monroe St            11.0    Michigan Ave & Oak St
# 1  Clinton St & Washington Blvd            31.0     Wells St & Walton St
# 2  Sheffield Ave & Kingsbury St            15.0  Dearborn St & Monroe St
#
#    end_capacity  temperature  wind_speed        events
# 0          15.0         73.9        12.7  mostlycloudy
# 1          19.0         69.1         6.9  partlycloudy
# 2          23.0         73.0        16.1  mostlycloudy

# %%
s = bikes['tripduration']
s.head()
# Out:
# 0     993
# 1     623
# 2    1040
# 3     667
# 4     130
# Name: tripduration, dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %% [markdown]
# **Exercise 1**
# -
# Select the column `events`, the type of weather was recorded, and assing it to a variable the same name. Output the first 10 values of it

# %%
events = bikes['events']
events.head(10)
# Out:
# 0    mostlycloudy
# 1    partlycloudy
# 2    mostlycloudy
# 3    mostlycloudy
# 4    partlycloudy
# 5    mostlycloudy
# 6          cloudy
# 7          cloudy
# 8          cloudy
# 9    mostlycloudy
# Name: events, dtype: object

# %% [markdown]
# **Exercice 2**
# -
# What type of object is `events`?

# %%
type(events)
# Out:
# pandas.core.series.Series

# %% [markdown]
# **Exercice 3**
# -
# Select the last two rows of the `bikes` DataFrame and assing it to the variable `bikes_last_2`. What type of object is `bikes_last_2`?

# %%
bikes_last_2 = bikes.tail(2)
type(bikes_last_2)
# Out:
# pandas.core.frame.DataFrame

# %%
bikes['end_capacity']
# Out:
# 0        15.0
# 1        19.0
# 2        23.0
# 3        31.0
# 4        19.0
#          ...
# 50084    27.0
# 50085    11.0
# 50086    20.0
# 50087    31.0
# 50088    15.0
# Name: end_capacity, Length: 50089, dtype: float64

# %%
bikes['start_capacity']
# Out:
# 0        11.0
# 1        31.0
# 2        15.0
# 3        19.0
# 4        19.0
#          ...
# 50084    27.0
# 50085    16.0
# 50086    31.0
# 50087    23.0
# 50088    15.0
# Name: start_capacity, Length: 50089, dtype: float64

# %%
bikes.dtypes
# Out:
# gender                object
# starttime             object
# stoptime              object
# tripduration           int64
# from_station_name     object
# start_capacity       float64
# to_station_name       object
# end_capacity         float64
# temperature          float64
# wind_speed           float64
# events                object
# dtype: object

# %%
type(bikes.shape)
# Out:
# tuple

# %%
bikes.dtypes
# Out:
# gender                object
# starttime             object
# stoptime              object
# tripduration           int64
# from_station_name     object
# start_capacity       float64
# to_station_name       object
# end_capacity         float64
# temperature          float64
# wind_speed           float64
# events                object
# dtype: object

# %%
bikes = pd.read_csv("../data/Master_Data_Analysis/bikes.csv", parse_dates=['starttime', 'stoptime'])
bikes.head()
# Out:
#   gender           starttime            stoptime  tripduration  \
# 0   Male 2013-06-28 19:01:00 2013-06-28 19:17:00           993
# 1   Male 2013-06-28 22:53:00 2013-06-28 23:03:00           623
# 2   Male 2013-06-30 14:43:00 2013-06-30 15:01:00          1040
# 3   Male 2013-07-01 10:05:00 2013-07-01 10:16:00           667
# 4   Male 2013-07-01 11:16:00 2013-07-01 11:18:00           130
#
#               from_station_name  start_capacity          to_station_name  \
# 0     Lake Shore Dr & Monroe St            11.0    Michigan Ave & Oak St
# 1  Clinton St & Washington Blvd            31.0     Wells St & Walton St
# 2  Sheffield Ave & Kingsbury St            15.0  Dearborn St & Monroe St
# 3       Carpenter St & Huron St            19.0   Clark St & Randolph St
# 4        Damen Ave & Pierce Ave            19.0   Damen Ave & Pierce Ave
#
#    end_capacity  temperature  wind_speed        events
# 0          15.0         73.9        12.7  mostlycloudy
# 1          19.0         69.1         6.9  partlycloudy
# 2          23.0         73.0        16.1  mostlycloudy
# 3          31.0         72.0        16.1  mostlycloudy
# 4          19.0         73.0        17.3  partlycloudy

# %%
bikes.dtypes
# Out:
# gender                       object
# starttime            datetime64[ns]
# stoptime             datetime64[ns]
# tripduration                  int64
# from_station_name            object
# start_capacity              float64
# to_station_name              object
# end_capacity                float64
# temperature                 float64
# wind_speed                  float64
# events                       object
# dtype: object

# %%
2 ** 63
# Out:
# 9223372036854775808

# %%
bikes.shape
# Out:
# (50089, 11)

# %%
bikes.size
# Out:
# 550979

# %%
len(bikes)
# Out:
# 50089

# %%
bikes.shape[0]
# Out:
# 50089

# %%
bikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50089 entries, 0 to 50088
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             50089 non-null  object
#  1   starttime          50089 non-null  datetime64[ns]
#  2   stoptime           50089 non-null  datetime64[ns]
#  3   tripduration       50089 non-null  int64
#  4   from_station_name  50089 non-null  object
#  5   start_capacity     50083 non-null  float64
#  6   to_station_name    50089 non-null  object
#  7   end_capacity       50077 non-null  float64
#  8   temperature        50089 non-null  float64
#  9   wind_speed         50089 non-null  float64
#  10  events             50089 non-null  object
# dtypes: datetime64[ns](2), float64(4), int64(1), object(4)
# memory usage: 4.2+ MB

# %%
s = bikes.dtypes
s
# Out:
# gender                       object
# starttime            datetime64[ns]
# stoptime             datetime64[ns]
# tripduration                  int64
# from_station_name            object
# start_capacity              float64
# to_station_name              object
# end_capacity                float64
# temperature                 float64
# wind_speed                  float64
# events                       object
# dtype: object

# %%
bikes.shape
# Out:
# (50089, 11)

# %%
df = pd.read_csv('../data/Master_Data_Analysis/sample_data.csv')
df
# Out:
#         name state  color    food  age  height  score
# 0       Jane    NY   blue   Steak   30     165    4.6
# 1       Niko    TX  green    Lamb    2      70    8.3
# 2      Aaron    FL    red   Mango   12     120    9.0
# 3   Penelope    AL  white   Apple    4      80    3.3
# 4       Dean    AK   gray  Cheese   32     180    1.8
# 5  Christina    TX  black   Melon   33     172    9.5
# 6   Cornelia    TX    red   Beans   69     150    2.2

# %%
df.set_index('name')
# Out:
#           state  color    food  age  height  score
# name
# Jane         NY   blue   Steak   30     165    4.6
# Niko         TX  green    Lamb    2      70    8.3
# Aaron        FL    red   Mango   12     120    9.0
# Penelope     AL  white   Apple    4      80    3.3
# Dean         AK   gray  Cheese   32     180    1.8
# Christina    TX  black   Melon   33     172    9.5
# Cornelia     TX    red   Beans   69     150    2.2

# %%
df
# Out:
#         name state  color    food  age  height  score
# 0       Jane    NY   blue   Steak   30     165    4.6
# 1       Niko    TX  green    Lamb    2      70    8.3
# 2      Aaron    FL    red   Mango   12     120    9.0
# 3   Penelope    AL  white   Apple    4      80    3.3
# 4       Dean    AK   gray  Cheese   32     180    1.8
# 5  Christina    TX  black   Melon   33     172    9.5
# 6   Cornelia    TX    red   Beans   69     150    2.2

# %%
df2 = df.set_index('name')
df2
# Out:
#           state  color    food  age  height  score
# name
# Jane         NY   blue   Steak   30     165    4.6
# Niko         TX  green    Lamb    2      70    8.3
# Aaron        FL    red   Mango   12     120    9.0
# Penelope     AL  white   Apple    4      80    3.3
# Dean         AK   gray  Cheese   32     180    1.8
# Christina    TX  black   Melon   33     172    9.5
# Cornelia     TX    red   Beans   69     150    2.2

# %%
df2.index
# Out:
# Index(['Jane', 'Niko', 'Aaron', 'Penelope', 'Dean', 'Christina', 'Cornelia'], dtype='object', name='name')

# %%
df2.columns
# Out:
# Index(['state', 'color', 'food', 'age', 'height', 'score'], dtype='object')

# %%
df2.values
# Out:
# array([['NY', 'blue', 'Steak', 30, 165, 4.6],
#        ['TX', 'green', 'Lamb', 2, 70, 8.3],
#        ['FL', 'red', 'Mango', 12, 120, 9.0],
#        ['AL', 'white', 'Apple', 4, 80, 3.3],
#        ['AK', 'gray', 'Cheese', 32, 180, 1.8],
#        ['TX', 'black', 'Melon', 33, 172, 9.5],
#        ['TX', 'red', 'Beans', 69, 150, 2.2]], dtype=object)

# %%
df2["food"] # Return a Series of the values into food column

df2["food"].values # Return a Array of the values food
# Out:
# array(['Steak', 'Lamb', 'Mango', 'Apple', 'Cheese', 'Melon', 'Beans'],
#       dtype=object)

# %%
s = df2["color"] # It's a simple Series
s
# Out:
# name
# Jane          blue
# Niko         green
# Aaron          red
# Penelope     white
# Dean          gray
# Christina    black
# Cornelia       red
# Name: color, dtype: object

# %%
s.index
# Out:
# Index(['Jane', 'Niko', 'Aaron', 'Penelope', 'Dean', 'Christina', 'Cornelia'], dtype='object', name='name')

# %%
s.values
# Out:
# array(['blue', 'green', 'red', 'white', 'gray', 'black', 'red'],
#       dtype=object)

# %%
movie = pd.read_csv("../data/Master_Data_Analysis/movie.csv")
movie.head(3)
# Out:
#                                       title    year  color content_rating  \
# 0                                    Avatar  2009.0  Color          PG-13
# 1  Pirates of the Caribbean: At World's End  2007.0  Color          PG-13
# 2                                   Spectre  2015.0  Color          PG-13
#
#    duration   director_name  director_fb           actor1  actor1_fb  \
# 0     178.0   James Cameron          0.0      CCH Pounder     1000.0
# 1     169.0  Gore Verbinski        563.0      Johnny Depp    40000.0
# 2     148.0      Sam Mendes          0.0  Christoph Waltz    11000.0
#
#              actor2  ...  actor3_fb        gross  \
# 0  Joel David Moore  ...      855.0  760505847.0
# 1     Orlando Bloom  ...     1000.0  309404152.0
# 2      Rory Kinnear  ...      161.0  200074175.0
#
#                             genres  num_reviews num_voted_users  \
# 0  Action|Adventure|Fantasy|Sci-Fi        723.0          886204
# 1         Action|Adventure|Fantasy        302.0          471220
# 2        Action|Adventure|Thriller        602.0          275868
#
#                                        plot_keywords  language country  \
# 0             avatar|future|marine|native|paraplegic   English     USA
# 1  goddess|marriage ceremony|marriage proposal|pi...   English     USA
# 2                bomb|espionage|sequel|spy|terrorist   English      UK
#
#         budget imdb_score
# 0  237000000.0        7.9
# 1  300000000.0        7.1
# 2  245000000.0        6.8
#
# [3 rows x 22 columns]

# %%
movie.index
# Out:
# RangeIndex(start=0, stop=4916, step=1)

# %%
range(100, 500, 4)
# Out:
# range(100, 500, 4)

# %%
idx = movie.index
idx
# Out:
# Index(['Avatar', 'Pirates of the Caribbean: At World's End', 'Spectre',
#        'The Dark Knight Rises', 'Star Wars: Episode VII - The Force Awakens',
#        'John Carter', 'Spider-Man 3', 'Tangled', 'Avengers: Age of Ultron',
#        'Harry Potter and the Half-Blood Prince',
#        ...
#        'Primer', 'Cavite', 'El Mariachi', 'The Mongol King', 'Newlyweds',
#        'Signed Sealed Delivered', 'The Following', 'A Plague So Pleasant',
#        'Shanghai Calling', 'My Date with Drew'],
#       dtype='object', name='title', length=4916)

# %%
idx[4000]
# Out:
# 'Before Midnight'

# %%
idx[40:100:20]
# Out:
# Index(['TRON: Legacy', '2012', 'Iron Man 2'], dtype='object', name='title')

# %%
idx[[50, 70, 3000]]
# Out:
# Index(['The Great Gatsby', 'Hugo', 'Quartet'], dtype='object', name='title')

# %%
movie.set_index('color', verify_integrity=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11452\977194859.py in ?()
# ----> 1 movie.set_index('color', verify_integrity=True)
#
# c:\Users\onlin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6178         index = ensure_index_from_sequences(arrays, names)
#    6179
#    6180         if verify_integrity and not index.is_unique:
#    6181             duplicates = index[index.duplicated()].unique()
# -> 6182             raise ValueError(f"Index has duplicate keys: {duplicates}")
#    6183
#    6184         # use set to handle duplicate column names gracefully in case of drop
#    6185         for c in set(to_remove):
#
# ValueError: Index has duplicate keys: Index(['Color', 'Black and White', nan], dtype='object', name='color')

# %%
movie.set_index('color')
# Out:
#          year content_rating  duration      director_name  director_fb  \
# color
# Color  2009.0          PG-13     178.0      James Cameron          0.0
# Color  2007.0          PG-13     169.0     Gore Verbinski        563.0
# Color  2015.0          PG-13     148.0         Sam Mendes          0.0
# Color  2012.0          PG-13     164.0  Christopher Nolan      22000.0
# NaN       NaN            NaN       NaN        Doug Walker        131.0
# ...       ...            ...       ...                ...          ...
# Color  2013.0            NaN      87.0        Scott Smith          2.0
# Color     NaN          TV-14      43.0                NaN          NaN
# Color  2013.0            NaN      76.0   Benjamin Roberds          0.0
# Color  2012.0          PG-13     100.0        Daniel Hsia          0.0
# Color  2004.0             PG      90.0           Jon Gunn         16.0
#
#                 actor1  actor1_fb            actor2  actor2_fb  \
# color
# Color      CCH Pounder     1000.0  Joel David Moore      936.0
# Color      Johnny Depp    40000.0     Orlando Bloom     5000.0
# Color  Christoph Waltz    11000.0      Rory Kinnear      393.0
# Color        Tom Hardy    27000.0    Christian Bale    23000.0
# NaN        Doug Walker      131.0        Rob Walker       12.0
# ...                ...        ...               ...        ...
# Color      Eric Mabius      637.0     Daphne Zuniga      470.0
# Color      Natalie Zea      841.0     Valorie Curry      593.0
# Color      Eva Boehnke        0.0     Maxwell Moody        0.0
# Color        Alan Ruck      946.0     Daniel Henney      719.0
# Color      John August       86.0  Brian Herzlinger       23.0
#
#                      actor3  actor3_fb        gross  \
# color
# Color             Wes Studi      855.0  760505847.0
# Color        Jack Davenport     1000.0  309404152.0
# Color      Stephanie Sigman      161.0  200074175.0
# Color  Joseph Gordon-Levitt    23000.0  448130642.0
# NaN                     NaN        NaN          NaN
# ...                     ...        ...          ...
# Color          Crystal Lowe      318.0          NaN
# Color         Sam Underwood      319.0          NaN
# Color        David Chandler        0.0          NaN
# Color           Eliza Coupe      489.0      10443.0
# Color              Jon Gunn       16.0      85222.0
#
#                                 genres  num_reviews  num_voted_users  \
# color
# Color  Action|Adventure|Fantasy|Sci-Fi        723.0           886204
# Color         Action|Adventure|Fantasy        302.0           471220
# Color        Action|Adventure|Thriller        602.0           275868
# Color                  Action|Thriller        813.0          1144337
# NaN                        Documentary          NaN                8
# ...                                ...          ...              ...
# Color                     Comedy|Drama          1.0              629
# Color     Crime|Drama|Mystery|Thriller         43.0            73839
# Color            Drama|Horror|Thriller         13.0               38
# Color             Comedy|Drama|Romance         14.0             1255
# Color                      Documentary         43.0             4285
#
#                                            plot_keywords language country  \
# color
# Color             avatar|future|marine|native|paraplegic  English     USA
# Color  goddess|marriage ceremony|marriage proposal|pi...  English     USA
# Color                bomb|espionage|sequel|spy|terrorist  English      UK
# Color  deception|imprisonment|lawlessness|police offi...  English     USA
# NaN                                                  NaN      NaN     NaN
# ...                                                  ...      ...     ...
# Color             fraud|postal worker|prison|theft|trial  English  Canada
# Color       cult|fbi|hideout|prison escape|serial killer  English     USA
# Color                                                NaN  English     USA
# Color                                                NaN  English     USA
# Color  actress name in title|crush|date|four word tit...  English     USA
#
#             budget  imdb_score
# color
# Color  237000000.0         7.9
# Color  300000000.0         7.1
# Color  245000000.0         6.8
# Color  250000000.0         8.5
# NaN            NaN         7.1
# ...            ...         ...
# Color          NaN         7.7
# Color          NaN         7.5
# Color       1400.0         6.3
# Color          NaN         6.3
# Color       1100.0         6.6
#
# [4916 rows x 20 columns]

# %%
movie.head(3)
# Out:
#                                             year  color content_rating  \
# title
# Avatar                                    2009.0  Color          PG-13
# Pirates of the Caribbean: At World's End  2007.0  Color          PG-13
# Spectre                                   2015.0  Color          PG-13
#
#                                           duration   director_name  \
# title
# Avatar                                       178.0   James Cameron
# Pirates of the Caribbean: At World's End     169.0  Gore Verbinski
# Spectre                                      148.0      Sam Mendes
#
#                                           director_fb           actor1  \
# title
# Avatar                                            0.0      CCH Pounder
# Pirates of the Caribbean: At World's End        563.0      Johnny Depp
# Spectre                                           0.0  Christoph Waltz
#
#                                           actor1_fb            actor2  \
# title
# Avatar                                       1000.0  Joel David Moore
# Pirates of the Caribbean: At World's End    40000.0     Orlando Bloom
# Spectre                                     11000.0      Rory Kinnear
#
#                                           actor2_fb  ... actor3_fb  \
# title                                                ...
# Avatar                                        936.0  ...     855.0
# Pirates of the Caribbean: At World's End     5000.0  ...    1000.0
# Spectre                                       393.0  ...     161.0
#
#                                                 gross  \
# title
# Avatar                                    760505847.0
# Pirates of the Caribbean: At World's End  309404152.0
# Spectre                                   200074175.0
#
#                                                                    genres  \
# title
# Avatar                                    Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End         Action|Adventure|Fantasy
# Spectre                                         Action|Adventure|Thriller
#
#                                          num_reviews  num_voted_users  \
# title
# Avatar                                         723.0           886204
# Pirates of the Caribbean: At World's End       302.0           471220
# Spectre                                        602.0           275868
#
#                                                                               plot_keywords  \
# title
# Avatar                                               avatar|future|marine|native|paraplegic
# Pirates of the Caribbean: At World's End  goddess|marriage ceremony|marriage proposal|pi...
# Spectre                                                 bomb|espionage|sequel|spy|terrorist
#
#                                          language country       budget  \
# title
# Avatar                                    English     USA  237000000.0
# Pirates of the Caribbean: At World's End  English     USA  300000000.0
# Spectre                                   English      UK  245000000.0
#
#                                           imdb_score
# title
# Avatar                                           7.9
# Pirates of the Caribbean: At World's End         7.1
# Spectre                                          6.8
#
# [3 rows x 21 columns]

# %%
movie.index[-10:]
# Out:
# Index(['Primer', 'Cavite', 'El Mariachi', 'The Mongol King', 'Newlyweds',
#        'Signed Sealed Delivered', 'The Following', 'A Plague So Pleasant',
#        'Shanghai Calling', 'My Date with Drew'],
#       dtype='object', name='title')

# %%
movie = pd.read_csv("../data/Master_Data_Analysis/movie.csv", index_col=6)
movie.head()
# Out:
#                                                   title    year  color  \
# director_fb
# 0.0                                              Avatar  2009.0  Color
# 563.0          Pirates of the Caribbean: At World's End  2007.0  Color
# 0.0                                             Spectre  2015.0  Color
# 22000.0                           The Dark Knight Rises  2012.0  Color
# 131.0        Star Wars: Episode VII - The Force Awakens     NaN    NaN
#
#             content_rating  duration      director_name           actor1  \
# director_fb
# 0.0                  PG-13     178.0      James Cameron      CCH Pounder
# 563.0                PG-13     169.0     Gore Verbinski      Johnny Depp
# 0.0                  PG-13     148.0         Sam Mendes  Christoph Waltz
# 22000.0              PG-13     164.0  Christopher Nolan        Tom Hardy
# 131.0                  NaN       NaN        Doug Walker      Doug Walker
#
#              actor1_fb            actor2  actor2_fb  ... actor3_fb  \
# director_fb                                          ...
# 0.0             1000.0  Joel David Moore      936.0  ...     855.0
# 563.0          40000.0     Orlando Bloom     5000.0  ...    1000.0
# 0.0            11000.0      Rory Kinnear      393.0  ...     161.0
# 22000.0        27000.0    Christian Bale    23000.0  ...   23000.0
# 131.0            131.0        Rob Walker       12.0  ...       NaN
#
#                    gross                           genres num_reviews  \
# director_fb
# 0.0          760505847.0  Action|Adventure|Fantasy|Sci-Fi       723.0
# 563.0        309404152.0         Action|Adventure|Fantasy       302.0
# 0.0          200074175.0        Action|Adventure|Thriller       602.0
# 22000.0      448130642.0                  Action|Thriller       813.0
# 131.0                NaN                      Documentary         NaN
#
#              num_voted_users  \
# director_fb
# 0.0                   886204
# 563.0                 471220
# 0.0                   275868
# 22000.0              1144337
# 131.0                      8
#
#                                                  plot_keywords language  \
# director_fb
# 0.0                     avatar|future|marine|native|paraplegic  English
# 563.0        goddess|marriage ceremony|marriage proposal|pi...  English
# 0.0                        bomb|espionage|sequel|spy|terrorist  English
# 22000.0      deception|imprisonment|lawlessness|police offi...  English
# 131.0                                                      NaN      NaN
#
#             country       budget  imdb_score
# director_fb
# 0.0             USA  237000000.0         7.9
# 563.0           USA  300000000.0         7.1
# 0.0              UK  245000000.0         6.8
# 22000.0         USA  250000000.0         8.5
# 131.0           NaN          NaN         7.1
#
# [5 rows x 21 columns]

# %%
movie.set_index('title')
# Out:
#                                               year  color content_rating  \
# title
# Avatar                                      2009.0  Color          PG-13
# Pirates of the Caribbean: At World's End    2007.0  Color          PG-13
# Spectre                                     2015.0  Color          PG-13
# The Dark Knight Rises                       2012.0  Color          PG-13
# Star Wars: Episode VII - The Force Awakens     NaN    NaN            NaN
# ...                                            ...    ...            ...
# Signed Sealed Delivered                     2013.0  Color            NaN
# The Following                                  NaN  Color          TV-14
# A Plague So Pleasant                        2013.0  Color            NaN
# Shanghai Calling                            2012.0  Color          PG-13
# My Date with Drew                           2004.0  Color             PG
#
#                                             duration      director_name  \
# title
# Avatar                                         178.0      James Cameron
# Pirates of the Caribbean: At World's End       169.0     Gore Verbinski
# Spectre                                        148.0         Sam Mendes
# The Dark Knight Rises                          164.0  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens       NaN        Doug Walker
# ...                                              ...                ...
# Signed Sealed Delivered                         87.0        Scott Smith
# The Following                                   43.0                NaN
# A Plague So Pleasant                            76.0   Benjamin Roberds
# Shanghai Calling                               100.0        Daniel Hsia
# My Date with Drew                               90.0           Jon Gunn
#
#                                                      actor1  actor1_fb  \
# title
# Avatar                                          CCH Pounder     1000.0
# Pirates of the Caribbean: At World's End        Johnny Depp    40000.0
# Spectre                                     Christoph Waltz    11000.0
# The Dark Knight Rises                             Tom Hardy    27000.0
# Star Wars: Episode VII - The Force Awakens      Doug Walker      131.0
# ...                                                     ...        ...
# Signed Sealed Delivered                         Eric Mabius      637.0
# The Following                                   Natalie Zea      841.0
# A Plague So Pleasant                            Eva Boehnke        0.0
# Shanghai Calling                                  Alan Ruck      946.0
# My Date with Drew                               John August       86.0
#
#                                                       actor2  actor2_fb  \
# title
# Avatar                                      Joel David Moore      936.0
# Pirates of the Caribbean: At World's End       Orlando Bloom     5000.0
# Spectre                                         Rory Kinnear      393.0
# The Dark Knight Rises                         Christian Bale    23000.0
# Star Wars: Episode VII - The Force Awakens        Rob Walker       12.0
# ...                                                      ...        ...
# Signed Sealed Delivered                        Daphne Zuniga      470.0
# The Following                                  Valorie Curry      593.0
# A Plague So Pleasant                           Maxwell Moody        0.0
# Shanghai Calling                               Daniel Henney      719.0
# My Date with Drew                           Brian Herzlinger       23.0
#
#                                                           actor3  actor3_fb  \
# title
# Avatar                                                 Wes Studi      855.0
# Pirates of the Caribbean: At World's End          Jack Davenport     1000.0
# Spectre                                         Stephanie Sigman      161.0
# The Dark Knight Rises                       Joseph Gordon-Levitt    23000.0
# Star Wars: Episode VII - The Force Awakens                   NaN        NaN
# ...                                                          ...        ...
# Signed Sealed Delivered                             Crystal Lowe      318.0
# The Following                                      Sam Underwood      319.0
# A Plague So Pleasant                              David Chandler        0.0
# Shanghai Calling                                     Eliza Coupe      489.0
# My Date with Drew                                       Jon Gunn       16.0
#
#                                                   gross  \
# title
# Avatar                                      760505847.0
# Pirates of the Caribbean: At World's End    309404152.0
# Spectre                                     200074175.0
# The Dark Knight Rises                       448130642.0
# Star Wars: Episode VII - The Force Awakens          NaN
# ...                                                 ...
# Signed Sealed Delivered                             NaN
# The Following                                       NaN
# A Plague So Pleasant                                NaN
# Shanghai Calling                                10443.0
# My Date with Drew                               85222.0
#
#                                                                      genres  \
# title
# Avatar                                      Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End           Action|Adventure|Fantasy
# Spectre                                           Action|Adventure|Thriller
# The Dark Knight Rises                                       Action|Thriller
# Star Wars: Episode VII - The Force Awakens                      Documentary
# ...                                                                     ...
# Signed Sealed Delivered                                        Comedy|Drama
# The Following                                  Crime|Drama|Mystery|Thriller
# A Plague So Pleasant                                  Drama|Horror|Thriller
# Shanghai Calling                                       Comedy|Drama|Romance
# My Date with Drew                                               Documentary
#
#                                             num_reviews  num_voted_users  \
# title
# Avatar                                            723.0           886204
# Pirates of the Caribbean: At World's End          302.0           471220
# Spectre                                           602.0           275868
# The Dark Knight Rises                             813.0          1144337
# Star Wars: Episode VII - The Force Awakens          NaN                8
# ...                                                 ...              ...
# Signed Sealed Delivered                             1.0              629
# The Following                                      43.0            73839
# A Plague So Pleasant                               13.0               38
# Shanghai Calling                                   14.0             1255
# My Date with Drew                                  43.0             4285
#
#                                                                                 plot_keywords  \
# title
# Avatar                                                 avatar|future|marine|native|paraplegic
# Pirates of the Caribbean: At World's End    goddess|marriage ceremony|marriage proposal|pi...
# Spectre                                                   bomb|espionage|sequel|spy|terrorist
# The Dark Knight Rises                       deception|imprisonment|lawlessness|police offi...
# Star Wars: Episode VII - The Force Awakens                                                NaN
# ...                                                                                       ...
# Signed Sealed Delivered                                fraud|postal worker|prison|theft|trial
# The Following                                    cult|fbi|hideout|prison escape|serial killer
# A Plague So Pleasant                                                                      NaN
# Shanghai Calling                                                                          NaN
# My Date with Drew                           actress name in title|crush|date|four word tit...
#
#                                            language country       budget  \
# title
# Avatar                                      English     USA  237000000.0
# Pirates of the Caribbean: At World's End    English     USA  300000000.0
# Spectre                                     English      UK  245000000.0
# The Dark Knight Rises                       English     USA  250000000.0
# Star Wars: Episode VII - The Force Awakens      NaN     NaN          NaN
# ...                                             ...     ...          ...
# Signed Sealed Delivered                     English  Canada          NaN
# The Following                               English     USA          NaN
# A Plague So Pleasant                        English     USA       1400.0
# Shanghai Calling                            English     USA          NaN
# My Date with Drew                           English     USA       1100.0
#
#                                             imdb_score
# title
# Avatar                                             7.9
# Pirates of the Caribbean: At World's End           7.1
# Spectre                                            6.8
# The Dark Knight Rises                              8.5
# Star Wars: Episode VII - The Force Awakens         7.1
# ...                                                ...
# Signed Sealed Delivered                            7.7
# The Following                                      7.5
# A Plague So Pleasant                               6.3
# Shanghai Calling                                   6.3
# My Date with Drew                                  6.6
#
# [4916 rows x 20 columns]

# %%
movie3 = movie.set_index('title')

# %%
movie3 = movie.set_index('title')
movie3.head(3)
# Out:
#                                             year  color content_rating  \
# title
# Avatar                                    2009.0  Color          PG-13
# Pirates of the Caribbean: At World's End  2007.0  Color          PG-13
# Spectre                                   2015.0  Color          PG-13
#
#                                           duration   director_name  \
# title
# Avatar                                       178.0   James Cameron
# Pirates of the Caribbean: At World's End     169.0  Gore Verbinski
# Spectre                                      148.0      Sam Mendes
#
#                                                    actor1  actor1_fb  \
# title
# Avatar                                        CCH Pounder     1000.0
# Pirates of the Caribbean: At World's End      Johnny Depp    40000.0
# Spectre                                   Christoph Waltz    11000.0
#
#                                                     actor2  actor2_fb  \
# title
# Avatar                                    Joel David Moore      936.0
# Pirates of the Caribbean: At World's End     Orlando Bloom     5000.0
# Spectre                                       Rory Kinnear      393.0
#
#                                                     actor3  actor3_fb  \
# title
# Avatar                                           Wes Studi      855.0
# Pirates of the Caribbean: At World's End    Jack Davenport     1000.0
# Spectre                                   Stephanie Sigman      161.0
#
#                                                 gross  \
# title
# Avatar                                    760505847.0
# Pirates of the Caribbean: At World's End  309404152.0
# Spectre                                   200074175.0
#
#                                                                    genres  \
# title
# Avatar                                    Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End         Action|Adventure|Fantasy
# Spectre                                         Action|Adventure|Thriller
#
#                                           num_reviews  num_voted_users  \
# title
# Avatar                                          723.0           886204
# Pirates of the Caribbean: At World's End        302.0           471220
# Spectre                                         602.0           275868
#
#                                                                               plot_keywords  \
# title
# Avatar                                               avatar|future|marine|native|paraplegic
# Pirates of the Caribbean: At World's End  goddess|marriage ceremony|marriage proposal|pi...
# Spectre                                                 bomb|espionage|sequel|spy|terrorist
#
#                                          language country       budget  \
# title
# Avatar                                    English     USA  237000000.0
# Pirates of the Caribbean: At World's End  English     USA  300000000.0
# Spectre                                   English      UK  245000000.0
#
#                                           imdb_score
# title
# Avatar                                           7.9
# Pirates of the Caribbean: At World's End         7.1
# Spectre                                          6.8
